# %%
def total(*num):
    print("Args: ", num)

total(1, 2, 3, 4, 5)
# Out:
# Args:  (1, 2, 3, 4, 5)

# %%
def info(**data):
    print("Kwargs: ", data)

info(name="Biranchi", age=20, city="Bhubaneswar")
# Out:
# Kwargs:  {'name': 'Biranchi', 'age': 20, 'city': 'Bhubaneswar'}
