# %%
lines = ["Line 1\n", "Line 2\n", "Line 3\n"]
with open("write_lines_example", "w") as f:
    f.writelines(lines)
f.close()

# %%
f = open("write_example", "w")
f.write("This is an example of writing to a file.\n")
f.write("You can write multiple lines to the file.\n")
f.close()

# %%
f = open("sample_data/california_housing_test.csv","r")
content = f.read()
print(content)

f.close
